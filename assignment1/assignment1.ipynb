# %%
from PIL import Image

# %%
# !wget https://cdn.britannica.com/60/217660-050-DBCC409A/cheddar-cheese-wedge.jpg -O cheese.jpg
# Out:
# --2023-02-09 17:50:07--  https://cdn.britannica.com/60/217660-050-DBCC409A/cheddar-cheese-wedge.jpg
# Resolving cdn.britannica.com (cdn.britannica.com)... 13.227.219.129, 13.227.219.100, 13.227.219.47, ...
# Connecting to cdn.britannica.com (cdn.britannica.com)|13.227.219.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44916 (44K) [image/jpeg]
# Saving to: 'cheese.jpg'
#
#      0K .......... .......... .......... .......... ...       100%  997K=0.04s
#
# 2023-02-09 17:50:08 (997 KB/s) - 'cheese.jpg' saved [44916/44916]

# %%
img = Image.open('cheese.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x955 at 0x1ED54E2B5E0>

# %%
pixels = img.load()
for x in range(30):
    for y in range(30):
        pixels[x, y] = (0, 0, 0)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x955 at 0x1ED54E2B5E0>
